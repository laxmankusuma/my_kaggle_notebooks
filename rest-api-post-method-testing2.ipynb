# %%
import requests
import json

# %%
url = 'https://ma25u2sof5.execute-api.ap-south-1.amazonaws.com/beta/prediction'

# %%
request = {
    "url":"https://static3.depositphotos.com/1005855/202/i/600/depositphotos_2022172-stock-photo-top-hat.jpg"
}

# %%
responce = requests.post(url, data=json.dumps(request))
result = responce.json()

# %%
result

# %%
for x in range(60000):
    responce = requests.post(url, data=json.dumps(request))
    print(x , responce)
